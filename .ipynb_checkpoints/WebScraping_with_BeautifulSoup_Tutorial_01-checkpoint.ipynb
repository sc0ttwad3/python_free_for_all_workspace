# %% [markdown]
# # WebScraping with BeautifulSoup and Pandas
#
# Here's the [talk](https://www.youtube.com/watch?v=XQgXKtPSzUI) for further information
#
# And related [article](https://pythonprogramminglanguage.com/web-scraping-with-pandas-and-beautifulsoup/) that is meant for Python 2.x but removing tabulate() will reach the same result

# %%
import bs4
from urllib.request import urlopen as uReq
from os.path import basename
from urllib.parse import urljoin
from lxml import html
from lxml.cssselect import CSSSelector
import requests

page = requests.get("http://www.example.com").text
doc = html.fromstring(page)
link = doc.cssselect("a")[0]

print(link.text_content())
print(link.attrib['href'])
# Out:
# More information...
# http://www.iana.org/domains/example

# %% [markdown]
# Using to scrap data from a products page at NewEgg

# %%
from bs4 import BeautifulSoup as BS
#from urllib.request import urlopen as uReq

# Grab graphics cards
# NewEgg Worksatation Graphics Cards
source_url = 'https://www.newegg.com/Desktop-Graphics-Cards/SubCategory/ID-48?Tid=7709'

client = uReq(source_url) # open conn
page_html = client.read() # grab page
client.close() # close conn to be nice

# open file to create .csv of data
#   and write headers line
filename = "desktop-graphics-cards.csv"
f = open(filename, "w")
headers = "brand, product_name, shipping\n"
f.write(headers)

# Parse the html
soup = BS(page_html, "html.parser")

# traverse the graphics card page elements
containers = soup.findAll("div", {"class": "item-container"})

for container in containers:
    brand = container.div.div.a.img["title"]

    title_container = container.findAll("a", {"class": "item-title"})
    title = title_container[0].text.replace(",", "|")

    ship_container = container.findAll("li", {"class": "price-ship"})
    ship = ship_container[0].text.strip() # remove newlines, etc.

    print(brand)
    print(title)
    print(ship)

    f.write(brand + "," + title + "," + ship + "\n")

f.close()

print('\nNumber of graphics cards:')
print(len(containers))
# Out:
# Sapphire Tech
# Sapphire Radeon NITRO+ RX 580 4GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP w/ Backplate (UEFI)| 100411NT+4GL
# $4.99 Shipping
# GIGABYTE
# GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060WF2OC-3GD 3GB 192-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# $4.99 Shipping
# MSI
# MSI Radeon RX 570 DirectX 12 RX 570 ARMOR 4G OC 4GB 256-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready CrossFireX Support ATX Video Card
# $4.99 Shipping
# ASUS
# ASUS GeForce GTX 1070 DUAL-GTX1070-O8G 8GB 256-Bit GDDR5 PCI Express 3.0 HDCP Ready SLI Support Video Card
# Free Shipping
# AMD
# AMD Radeon Vega Frontier Edition DirectX 12 100-506061 16GB 2048-Bit HBM2 Video Card (Air Cooled Model)
# Free Shipping
# GIGABYTE
# GIGABYTE GeForce GTX 1060 DirectX 12 GV-N1060G1 GAMING-6GD 6GB 192-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# Free Shipping
# MSI
# MSI Radeon RX 570 DirectX 12 RX 570 GAMING X 4G 4GB 256-Bit GDDR5 PCI Express 3.0 HDCP Ready CrossFireX Support ATX Video Card
# $4.99 Shipping
# Sapphire Tech
# SAPPHIRE Radeon RX Vega 56 DirectX 12 100420L 8GB 2048-Bit HBM2 CrossFireX Support ATX Video Card
# $4.99 Shipping
# EVGA
# EVGA GeForce GTX 1070 FTW GAMING ACX 3.0| 08G-P4-6276-KR| 8GB GDDR5| RGB LED| 10CM FAN| 10 Power Phases| Double BIOS| DX12 OSD Support (PXOC)
# $4.99 Shipping
# AMD
# AMD Radeon Vega Frontier Edition DirectX 12.1 100-5056062 16GB 2048-Bit HBM2 Video Card (Liquid Cooled Model)
# $6.99 Shipping
# EVGA
# EVGA GeForce GTX 1050 Ti SC GAMING| 04G-P4-6253-KR| 4GB GDDR5| DX12 OSD Support (PXOC)
# $3.99 Shipping
# ASUS
# ASUS ROG GeForce GTX 1080 Ti DirectX 12 STRIX-GTX1080TI-11G-GAMING 11GB 352-Bit GDDR5X HDCP Ready SLI Support Video Card
# $4.99 Shipping
# ASUS
# ASUS GeForce GTX 1060 DUAL-GTX1060-O6G 6GB 192-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# $4.99 Shipping
# Sapphire Tech
# Sapphire NITRO+ Radeon RX 570 8GB GDDR5 PCI-E Dual HDMI / DVI-D / Dual DP w/ Backplate (UEFI)| 100412NT+8GL
# $4.99 Shipping
# EVGA
# EVGA GeForce GTX 1060 SC GAMING| ACX 2.0 (Single Fan)| 03G-P4-6162-KR| 3GB GDDR5| DX12 OSD Support (PXOC)
# $4.99 Shipping
# GIGABYTE
# GIGABYTE GeForce GTX 1050 Ti DirectX 12 GV-N105TWF2OC-4GD 4GB 128-Bit GDDR5 PCI Express 3.0 x16 ATX Video Card
# $3.99 Shipping
# GIGABYTE
# GIGABYTE GeForce GTX 1080 DirectX 12 GV-N1080D5X-8GD 8GB 256-Bit GDDR5X PCI Express 3.0 x16 ATX Video Cards
# $4.99 Shipping
# PowerColor
# PowerColor Radeon RX 560 DirectX 12 AXRX 560 4GBD5-AM 4GB 128-Bit GDDR5 PCI Express 3.0 CrossFireX Support ATX Mining Video Card - OEM
# $3.99 Shipping
# EVGA
# EVGA GeForce GTX 1060 GAMING| ACX 2.0 (Single Fan)| 03G-P4-6160-KR| 3GB GDDR5| DX12 OSD Support (PXOC)| Only 6.8 Inches
# $4.99 Shipping
# MSI
# MSI GeForce GTX 1070 DirectX 12 GTX 1070 GAMING 8G 8GB 256-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready SLI Support ATX Video Card
# $3.99 Shipping
# GIGABYTE
# GIGABYTE AORUS GeForce GTX 1080 Ti DirectX 12 GV-N108TAORUS-11GD 11GB 352-Bit GDDR5X PCI Express 3.0 x16 SLI Support ATX Video Card
# $4.99 Shipping
# Sapphire Tech
# SAPPHIRE Radeon RX VEGA 64 DirectX 12 100410L 8GB 2048-Bit HBM2 HDMI / TRIPLE DP (UEFI) PCI Express 3.0 CrossFireX Support ATX Video Card
# $4.99 Shipping
# GIGABYTE
# GIGABYTE AORUS XTREME GeForce GTX 1060 6G REV 2.0| GV-N1060AORUS-X6GDR2
# $3.99 Shipping
# MSI
# MSI GeForce GTX 1080 Ti DirectX 12 GTX 1080 Ti LIGHTNING X 11GB 352-Bit GDDR5X PCI Express 3.0 x16 HDCP Ready SLI Support Video Card
# $4.99 Shipping
# MSI
# MSI GeForce GT 1030 DirectX 12 GT 1030 2G LP OC 2GB 64-Bit GDDR5 PCI Express 3.0 x16 (uses x4) HDCP Ready Low Profile Video Card
# $3.99 Shipping
# MSI
# MSI Radeon RX 580 DirectX 12 RX 580 GAMING X 4G 4GB 256-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready CrossFireX Support Video Card
# Free Shipping
# ASUS
# ASUS ROG Strix Radeon RX 570 O4G Gaming OC Edition GDDR5 DP HDMI DVI VR Ready AMD Graphics Card (ROG-STRIX-RX570-O4G-GAMING)
# Free Shipping
# ZOTAC
# ZOTAC GeForce GTX 1080 Mini| ZT-P10800H-10P| 8GB GDDR5X IceStorm Cooling| Dual Fans| 90mm Pressure Optimized Fan| 100mm Maximum Airflow Optimized Fan| Direct GPU Copper Block Contact| Metal Back plate
# $4.99 Shipping
# PNY Technologies, Inc.
# PNY GeForce GTX 1060 DirectX 12 VCGGTX10606PB 6GB 192-Bit GDDR5 PCI Express 3.0 x16 Video Card
# Free Shipping
# MSI
# MSI GeForce GTX 1080 DirectX 12 GTX 1080 ARMOR 8G OC 8GB 256-Bit GDDR5X PCI Express 3.0 x16 HDCP Ready SLI Support ATX Video Card
# Free Shipping
# MSI
# MSI Radeon R7 250 DirectX 12 R7 250 2GD3 OC 2GB 128-Bit DDR3 PCI Express 3.0 HDCP Ready CrossFireX Support Video Card
# Free Shipping
# ASUS
# ASUS ROG GeForce GTX 1080 STRIX-GTX1080-A8G-GAMING 8GB 256-Bit GDDR5X PCI Express 3.0 HDCP Ready Video Card
# $4.99 Shipping
# GIGABYTE
# GIGABYTE GeForce GTX 1080 DirectX 12 GV-N1080TTOC-8GD 8GB 256-Bit GDDR5X PCI Express 3.0 x16 SLI Support ATX Turbo OC Video Card
# $4.99 Shipping
# MSI
# MSI GeForce GTX 1050 Ti DirectX 12 GTX 1050 TI 4GT LP 4GB 128-Bit GDDR5 PCI Express 3.0 x16 HDCP Ready Low Profile Video Card
# Free Shipping
# MSI
# MSI GeForce GTX 1080 Ti DirectX 12 GeForce GTX 1080 Ti GAMING X 11G 11GB 352-Bit GDDR5X PCI Express 3.0 x16 HDCP Ready SLI Support Video Card
# $4.99 Shipping
# ASUS
# ASUS GeForce GTX 1060 STRIX-GTX1060-O6G-GAMING 6GB 192-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# $4.99 Shipping
# ASUS
# ASUS GeForce GTX 1050 Ti DUAL-GTX1050TI-O4G 4GB 128-Bit GDDR5 PCI Express 3.0 HDCP Ready Video Card
# Free Shipping
#
# Number of graphics cards:
# 37

# %% [markdown]
# ### Adding Pandas for DataFrames

# %%
from bs4 import BeautifulSoup as BS
import pandas as pd
import requests

res = requests.get("http://www.nationmaster.com/country-info/stats/Media/Internet-users")
soup = BS(res.content, 'lxml')
table = soup.find_all('table')[0]
df = pd.read_html(str(table))
print(df[0])
# Out:
#         #                                        COUNTRY         AMOUNT  DATE  \
# 0       1                                          China    389 million  2009
# 1       2                                  United States    245 million  2009
# 2       3                                          Japan  99.18 million  2009
# 3     NaN    Group of 7 countries (G7) average (profile)  80.32 million  2009
# 4       4                                         Brazil  75.98 million  2009
# 5       5                                        Germany  65.12 million  2010
# 6       6                                          India  61.34 million  2009
# 7       7                                         Russia   59.7 million  2010
# 8     NaN      Non-religious countries average (profile)  51.56 million  2009
# 9       8                                 United Kingdom  51.44 million  2009
# 10      9                                         France  44.63 million  2010
# 11     10                                        Nigeria  43.99 million  2009
# 12     11                                    South Korea   39.4 million  2009
# 13     12                                         Turkey     35 million  2010
# 14    NaN             Emerging markets average (profile)  32.99 million  2009
# 15     13                                         Mexico  31.02 million  2009
# 16     14                                          Italy  30.03 million  2010
# 17     15                                          Spain  29.09 million  2010
# 18     16                                         Canada  26.96 million  2009
# 19    NaN        East Asia and Pacific average (profile)  25.43 million  2009
# 20    NaN   High income OECD countries average (profile)  24.75 million  2009
# 21    NaN               Cold countries average (profile)  23.69 million  2009
# 22     17                                        Vietnam  23.38 million  2009
# 23     18                                       Colombia  22.54 million  2009
# 24     19                                         Poland  22.45 million  2010
# 25     20                                       Pakistan  20.43 million  2009
# 26     21                                          Egypt  20.14 million  2009
# 27     22                                      Indonesia     20 million  2009
# 28    NaN   Heavily indebted countries average (profile)  17.81 million  2009
# 29     23                                       Thailand  17.48 million  2009
# ..    ...                                            ...            ...   ...
# 219  =189                                         Monaco          23000  2010
# 220  =189                                  Liechtenstein          23000  2010
# 221  =189                                 Cayman Islands          23000  2008
# 222   192                       Central African Republic          22600  2009
# 223   193                                      Gibraltar          20200  2009
# 224   194                                        Liberia          20000  2009
# 225  =195                                        Vanuatu          17000  2009
# 226  =195                                     San Marino          17000  2010
# 227  =195                 Federated States of Micronesia          17000  2009
# 228  =195                          Saint Kitts and Nevis          17000  2009
# 229   199                                   Sierra Leone          14900  2009
# 230   200                              Equatorial Guinea          14400  2009
# 231   201                                Solomon Islands          10000  2009
# 232   202                                          Samoa           9000  2009
# 233   203                                          Tonga           8400  2009
# 234   204                                       Kiribati           7800  2009
# 235   205                                   Cook Islands           6000  2009
# 236   206                                         Tuvalu           4200  2008
# 237   207                         British Virgin Islands           4000  2002
# 238   208                                       Anguilla           3700  2009
# 239   209              Falkland Islands (Islas Malvinas)           2900  2009
# 240   210                               Marshall Islands           2200  2009
# 241   211                                     East Timor           2100  2009
# 242   212                              Wallis and Futuna           1300  2009
# 243   213                                     Montserrat           1200  2009
# 244   214                                           Niue           1100  2009
# 245  =215  Saint Helena, Ascension, and Tristan da Cunha            900  2009
# 246  =215                                   Saint Helena            900  2009
# 247   217                                        Tokelau            800  2008
# 248   218                               Christmas Island            464  2001
#
#      GRAPH  HISTORY
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN
# 5      NaN      NaN
# 6      NaN      NaN
# 7      NaN      NaN
# 8      NaN      NaN
# 9      NaN      NaN
# 10     NaN      NaN
# 11     NaN      NaN
# 12     NaN      NaN
# 13     NaN      NaN
# 14     NaN      NaN
# 15     NaN      NaN
# 16     NaN      NaN
# 17     NaN      NaN
# 18     NaN      NaN
# 19     NaN      NaN
# 20     NaN      NaN
# 21     NaN      NaN
# 22     NaN      NaN
# 23     NaN      NaN
# 24     NaN      NaN
# 25     NaN      NaN
# 26     NaN      NaN
# 27     NaN      NaN
# 28     NaN      NaN
# 29     NaN      NaN
# ..     ...      ...
# 219    NaN      NaN
# 220    NaN      NaN
# 221    NaN      NaN
# 222    NaN      NaN
# 223    NaN      NaN
# 224    NaN      NaN
# 225    NaN      NaN
# 226    NaN      NaN
# 227    NaN      NaN
# 228    NaN      NaN
# 229    NaN      NaN
# 230    NaN      NaN
# 231    NaN      NaN
# 232    NaN      NaN
# 233    NaN      NaN
# 234    NaN      NaN
# 235    NaN      NaN
# 236    NaN      NaN
# 237    NaN      NaN
# 238    NaN      NaN
# 239    NaN      NaN
# 240    NaN      NaN
# 241    NaN      NaN
# 242    NaN      NaN
# 243    NaN      NaN
# 244    NaN      NaN
# 245    NaN      NaN
# 246    NaN      NaN
# 247    NaN      NaN
# 248    NaN      NaN
#
# [249 rows x 6 columns]
