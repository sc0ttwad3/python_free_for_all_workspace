# %% [markdown]
# # Machine Learning Data Acquisition
#
# ## Project: Find Cheapest Air Fares
#
# Early work on headless browser and scraping data for analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
from bs4 import BeautifulSoup as BS

# %matplotlib inline

# %%
# instantiate headless browser obj
url = "https://www.google.com/flights/explore/#explore;f=SFO;t=r-Mexico-0x84043a3b88685353%253A0xed64b4be6b099811;s=1;li=8;lx=12;d=2017-10-16"

driver = webdriver.PhantomJS()
dcap = dict(DesiredCapabilities.PHANTOMJS)
dcap["phantomjs.page.settings.userAgent"] = ("Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3230.0 Safari/537.36")
driver = webdriver.PhantomJS(desired_capabilities=dcap,service_args=['--ignore-ssl-errors=true'])
driver.implicitly_wait(20)
driver.get(url)

# %%
# check to make sure of payload
driver.save_screenshot(r'flight_explorer.png')
# Out:
# True

# %%
##
#   Can't find a tag/selector that works for the rest of this project so far
#   PYTHON_MACHINE_LEARNING_BLUEPRINTS....pdf p.85
##
# parse payload extract pricing info
s = BS(driver.page_source, "lxml")

#best_price_tags = s.findAll('div', 'FTWFGDB-w-e')
#best_prices = []
#for tag in best_price_tags:
#    best_prices.append(int(tag.text.replace('$','')))
    
#best_price = best_prices[0]
#print(best_prices)

# %%
# Parse the html
soup = BS(driver.page_source, "html5lib")

# find the distinguishing tags and data for the sequence
#best_price_tags = soup.select("div.PN3Y3AB-f-e", {'elt': 'results'})
best_price_tags = soup.find_all("div", class_="PN3Y3AB-f-e")

# deal with each tag
for tag in best_price_tags:
    print(tag)
    print("----------------------------------------------------------------")
# Out:
# <div class="PN3Y3AB-f-e" elt="filterBar"><div class="PN3Y3AB-i-a"><table class="PN3Y3AB-i-c"><colgroup><col/><col/></colgroup><tbody><tr><td width="100%"><div class="PN3Y3AB-i-b"><div class="PN3Y3AB-c-b PN3Y3AB-n-d PN3Y3AB-n-a"><div class="gwt-HTML PN3Y3AB-n-f PN3Y3AB-n-c">Up to 1 stop</div></div><div class="PN3Y3AB-c-b PN3Y3AB-n-d"><div class="gwt-HTML PN3Y3AB-n-f PN3Y3AB-n-c">Airline</div></div></div></td><td> </td></tr></tbody></table></div></div>
# ----------------------------------------------------------------
# <div class="PN3Y3AB-f-e" elt="results"><div class=""><div class="PN3Y3AB-h-a">Lowest fares for trips of 8-12 days</div><div elt="results"><div><div class="PN3Y3AB-v-d"><div class="PN3Y3AB-v-b"><img class="PN3Y3AB-v-a" src="https://lh4.googleusercontent.com/proxy/Z1g1_NcaeDTdLL7oK7yP7rhy33OA-ZV0IaYbJrkfiR3mw8qnKvOdSIydU-Y5pOzGr3C8JYZ6HJ4PQeli8DjpYaMQ8bqXsT0XidwM9f5N5G0ZT-G1NoYAULWIJVKw9aS1375a65_roZBI=w230-h182-n"/><div class="PN3Y3AB-v-i">Photo: <a href="http://panoramio.com/photo/" target="_blank">Panoramio</a></div></div><div class="PN3Y3AB-v-m"><div class="PN3Y3AB-v-e"><div act="cityName" class="PN3Y3AB-v-l PN3Y3AB-c-b">Best price <span class="PN3Y3AB-v-k">$196</span></div><div act="nonstop" class="PN3Y3AB-v-h">Nonstop $196</div><div><span act="cityName" class="PN3Y3AB-v-c">Mexico City, Mexico</span></div></div><div elt="graph"><div class="PN3Y3AB-w-g"><